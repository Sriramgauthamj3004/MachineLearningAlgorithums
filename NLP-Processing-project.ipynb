# %%
import nltk
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import re # Regular Expression
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords

# %%
sample_text="""Films, often called movies, are a major part of our lives and culture. These are stories brought to life on big screens with moving pictures and sound. Each film starts as an idea, which then becomes a script. The script is like a guide for the movie, telling what happens and what people say. The people who act in the film are called actors. They play various roles, pretending to be someone else. Some films are based on true stories and some are imagined. Films are made in many genres, like comedy, action, drama, and horror, each offering a different experience. Comedies make us laugh, dramas make us think, horrors may scare us, and action films thrill us. Films can teach us about different people, cultures, and ideas, and can even make us see the world in a new way. They can also be a fun way to escape from the real world for a little while. Making a film requires a big team. Along with actors, there are directors who guide the filming process, camera operators who film the scenes, and editors who put all the parts together. After the film is made, it is shown in cinemas where we can watch it, usually with popcorn! Films are special because they tell stories in a way that no other art form can, combining visuals, sound, and performance all at once."""

# %%
sample_text
# Out:
# 'Films, often called movies, are a major part of our lives and culture. These are stories brought to life on big screens with moving pictures and sound. Each film starts as an idea, which then becomes a script. The script is like a guide for the movie, telling what happens and what people say. The people who act in the film are called actors. They play various roles, pretending to be someone else. Some films are based on true stories and some are imagined. Films are made in many genres, like comedy, action, drama, and horror, each offering a different experience. Comedies make us laugh, dramas make us think, horrors may scare us, and action films thrill us. Films can teach us about different people, cultures, and ideas, and can even make us see the world in a new way. They can also be a fun way to escape from the real world for a little while. Making a film requires a big team. Along with actors, there are directors who guide the filming process, camera operators who film the scenes,
# ...

# %%
sample_tokens = word_tokenize(sample_text)
sample_tokens
# Out:
# ['Films',
#  ',',
#  'often',
#  'called',
#  'movies',
#  ',',
#  'are',
#  'a',
#  'major',
#  'part',
#  'of',
#  'our',
#  'lives',
#  'and',
#  'culture',
#  '.',
#  'These',
#  'are',
#  'stories',
#  'brought',
#  'to',
#  'life',
#  'on',
#  'big',
#  'screens',
#  'with',
#  'moving',
#  'pictures',
#  'and',
#  'sound',
#  '.',
#  'Each',
#  'film',
#  'starts',
#  'as',
#  'an',
#  'idea',
#  ',',
#  'which',
#  'then',
#  'becomes',
#  'a',
#  'script',
#  '.',
#  'The',
#  'script',
#  'is',
#  'like',
#  'a',
#  'guide',
#  'for',
#  'the',
#  'movie',
#  ',',
#  'telling',
#  'what',
#  'happens',
#  'and',
#  'what',
#  'people',
#  'say',
#  '.',
#  'The',
#  'people',
#  'who',
#  'act',
#  'in',
#  'the',
#  'film',
#  'are',
#  'called',
#  'actors',
#  '.',
#  'They',
#  'play',
#  'various',
#  'roles',
#  ',',
#  'pretending',
#  'to',
#  'be',
#  'someone',
#  'else',
#  '.',
#  'Some',
#  'films',
#  'are',
#  'based',
#  'on',
#  'true',
#  'stories',
# ...

# %%
import pickle
with open("sample_tokens.pkl","wb") as mf:
    pickle.dump(sample_tokens,mf)

# %%
type(stopwords.words('english'))
# Out:
# list

# %%
stop_words = stopwords.words('english')

# %%
stop_words = set(stop_words)

# %%
sr_list = []
for i in sample_tokens:
    if i not in stop_words:
        print(i)
        sr_list.append(i)
# Out:
# Films
# ,
# often
# called
# movies
# ,
# major
# part
# lives
# culture
# .
# These
# stories
# brought
# life
# big
# screens
# moving
# pictures
# sound
# .
# Each
# film
# starts
# idea
# ,
# becomes
# script
# .
# The
# script
# like
# guide
# movie
# ,
# telling
# happens
# people
# say
# .
# The
# people
# act
# film
# called
# actors
# .
# They
# play
# various
# roles
# ,
# pretending
# someone
# else
# .
# Some
# films
# based
# true
# stories
# imagined
# .
# Films
# made
# many
# genres
# ,
# like
# comedy
# ,
# action
# ,
# drama
# ,
# horror
# ,
# offering
# different
# experience
# .
# Comedies
# make
# us
# laugh
# ,
# dramas
# make
# us
# think
# ,
# horrors
# may
# scare
# us
# ,
# action
# films
# thrill
# us
# .
# Films
# teach
# us
# different
# people
# ,
# cultures
# ,
# ideas
# ,
# even
# make
# us
# see
# world
# new
# way
# .
# They
# also
# fun
# way
# escape
# real
# world
# little
# .
# Making
# film
# requires
# big
# team
# .
# Along
# actors
# ,
# ...

# %%
sr_list = [i for i in sample_tokens if i not in stop_words ]

# %%
sr_list
# Out:
# ['Films',
#  ',',
#  'often',
#  'called',
#  'movies',
#  ',',
#  'major',
#  'part',
#  'lives',
#  'culture',
#  '.',
#  'These',
#  'stories',
#  'brought',
#  'life',
#  'big',
#  'screens',
#  'moving',
#  'pictures',
#  'sound',
#  '.',
#  'Each',
#  'film',
#  'starts',
#  'idea',
#  ',',
#  'becomes',
#  'script',
#  '.',
#  'The',
#  'script',
#  'like',
#  'guide',
#  'movie',
#  ',',
#  'telling',
#  'happens',
#  'people',
#  'say',
#  '.',
#  'The',
#  'people',
#  'act',
#  'film',
#  'called',
#  'actors',
#  '.',
#  'They',
#  'play',
#  'various',
#  'roles',
#  ',',
#  'pretending',
#  'someone',
#  'else',
#  '.',
#  'Some',
#  'films',
#  'based',
#  'true',
#  'stories',
#  'imagined',
#  '.',
#  'Films',
#  'made',
#  'many',
#  'genres',
#  ',',
#  'like',
#  'comedy',
#  ',',
#  'action',
#  ',',
#  'drama',
#  ',',
#  'horror',
#  ',',
#  'offering',
#  'different',
#  'experience',
#  '.',
#  'Comedies',
#  'make',
#  'us',
#  'laugh',
#  ',',
#  'dramas',
# ...

# %%
input_string = ' '.join(sr_list)

# %%
re.sub(r'\d+', ' ',input_string)
# Out:
# 'Films , often called movies , major part lives culture . These stories brought life big screens moving pictures sound . Each film starts idea , becomes script . The script like guide movie , telling happens people say . The people act film called actors . They play various roles , pretending someone else . Some films based true stories imagined . Films made many genres , like comedy , action , drama , horror , offering different experience . Comedies make us laugh , dramas make us think , horrors may scare us , action films thrill us . Films teach us different people , cultures , ideas , even make us see world new way . They also fun way escape real world little . Making film requires big team . Along actors , directors guide filming process , camera operators film scenes , editors put parts together . After film made , shown cinemas watch , usually popcorn ! Films special tell stories way art form , combining visuals , sound , performance .'

# %%
std_tokens = ['the',
 'wikiqa',
 'corpus',
 'is',
 'a',
 'new',
 'publicly',
 'available',
 'set',
 'of',
 'question',
 'and',
 'sentence',
 'pairs',
 ',',
 'collected',
 'and',
 'annotated',
 'for',
 'research',
 'on',
 'open-domain',
 'question',
 'answering',
 '.',
 'in',
 'order',
 'to',
 'reflect',
 'the',
 'true',
 'information',
 'need',
 'of',
 'general',
 'users',
 ',',
 'we',
 'used',
 'bing',
 'query',
 'logs',
 'as',
 'the',
 'question',
 'source',
 '.',
 'each',
 'question',
 'is',
 'linked',
 'to',
 'a',
 'wikipedia',
 'page',
 'that',
 'potentially',
 'has',
 'the',
 'answer',
 '.',
 'because',
 'the',
 'summary',
 'section',
 'of',
 'a',
 'wikipedia',
 'page',
 'provides',
 'the',
 'basic',
 'and',
 'usually',
 'most',
 'important',
 'information',
 'about',
 'the',
 'topic',
 ',',
 'we',
 'used',
 'sentences',
 'in',
 'this',
 'section',
 'as',
 'the',
 'candidate',
 'answers',
 '.',
 'with',
 'the',
 'help',
 'of',
 'crowdsourcing',
 ',',
 'we',
 'included',
 '3,047',
 'questions',
 'and',
 '29,258',
 'sentences',
 'in',
 'the',
 'dataset',
 ',',
 'where',
 '1,473',
 'sentences',
 'were',
 'labeled',
 'as',
 'answer',
 'sentences',
 'to',
 'their',
 'corresponding',
 'questions',
 '.',
 'more',
 'detail',
 'of',
 'this',
 'corpus',
 'can',
 'be',
 'found',
 'in',
 'our',
 'emnlp-2015',
 'paper',
 ',',
 '``',
 'wikiqa',
 ':',
 'a',
 'challenge',
 'dataset',
 'for',
 'open-domain',
 'question',
 'answering',
 "''",
 '[',
 'yang',
 'et',
 'al',
 '.',
 '2015',
 ']',
 '.',
 'in',
 'addition',
 ',',
 'this',
 'download',
 'also',
 'includes',
 'the',
 'experimental',
 'results',
 'in',
 'the',
 'paper',
 ',',
 'an',
 'evaluation',
 'script',
 'for',
 'judging',
 'the',
 '``',
 'answer',
 'triggering',
 "''",
 'task',
 ',',
 'as',
 'well',
 'as',
 'the',
 'answer',
 'phrases',
 'labeled',
 'by',
 'the',
 'authors',
 'of',
 'the',
 'paper',
 '.']

# %%
[re.sub(r'[^a-zA-Z0-9]', '', i )  for i in std_tokens]
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  '',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'opendomain',
#  'question',
#  'answering',
#  '',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  '',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  '',
#  'we',
#  'used',
#  'sentences',
#  'in',
# ...

# %%
[re.sub(r'\w+', '', i )  for i in std_tokens]
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '',
#  ',',
#  '``',
#  '',
#  ':',
#  '',
#  '',
# ...

# %%
! pip install pyspellchecker

# %%
from spellchecker import SpellChecker

# %%
checker = SpellChecker()

# %%
[checker.correction(i) for i in std_tokens]
# Out:
# ['the',
#  'wiki',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  None,
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'being',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  None,
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  None,
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
#  'in',
#  'this',
# ...

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
stemmer = PorterStemmer()

# %%
std_tokens
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
# ...

# %%
[stemmer.stem(i) for i in std_tokens]
# Out:
# ['the',
#  'wikiqa',
#  'corpu',
#  'is',
#  'a',
#  'new',
#  'publicli',
#  'avail',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentenc',
#  'pair',
#  ',',
#  'collect',
#  'and',
#  'annot',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answer',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'inform',
#  'need',
#  'of',
#  'gener',
#  'user',
#  ',',
#  'we',
#  'use',
#  'bing',
#  'queri',
#  'log',
#  'as',
#  'the',
#  'question',
#  'sourc',
#  '.',
#  'each',
#  'question',
#  'is',
#  'link',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potenti',
#  'ha',
#  'the',
#  'answer',
#  '.',
#  'becaus',
#  'the',
#  'summari',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provid',
#  'the',
#  'basic',
#  'and',
#  'usual',
#  'most',
#  'import',
#  'inform',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'use',
#  'sentenc',
#  'in',
#  'thi',
#  'section',
#  'as',
#  'the',
# ...

# %%
lemm = WordNetLemmatizer()

# %%
[lemm.lemmatize(i) for i in std_tokens]
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pair',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'user',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'log',
#  'a',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'ha',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentence',
#  'in',
# ...

# %%
import nltk

# %%
input_sent = "Films, often called movies, are a major part of our lives and culture. These are stories brought to life on big screens with moving pictures and sound. Each film starts as an idea, which then becomes a script. The script is like a guide for the movie, telling what happens and what people say. The people who act in the film are called actors. They play various roles, pretending to be someone else. Some films are based on true stories and some are imagined. Films are made in many genres, like comedy, action, drama, and horror, each offering a different experience. Comedies make us laugh, dramas make us think, horrors may scare us, and action films thrill us. Films can teach us about different people, cultures, and ideas, and can even make us see the world in a new way. They can also be a fun way to escape from the real world for a little while. Making a film requires a big team. Along with actors, there are directors who guide the filming process, camera operators who film the scenes, and editors who put all the parts together. After the film is made, it is shown in cinemas where we can watch it, usually with popcorn! Films are special because they tell stories in a way that no other art form can, combining visuals, sound, and performance all at once."

# %%
tokens = nltk.word_tokenize(input_sent)

# %%
tokens
# Out:
# ['Films',
#  ',',
#  'often',
#  'called',
#  'movies',
#  ',',
#  'are',
#  'a',
#  'major',
#  'part',
#  'of',
#  'our',
#  'lives',
#  'and',
#  'culture',
#  '.',
#  'These',
#  'are',
#  'stories',
#  'brought',
#  'to',
#  'life',
#  'on',
#  'big',
#  'screens',
#  'with',
#  'moving',
#  'pictures',
#  'and',
#  'sound',
#  '.',
#  'Each',
#  'film',
#  'starts',
#  'as',
#  'an',
#  'idea',
#  ',',
#  'which',
#  'then',
#  'becomes',
#  'a',
#  'script',
#  '.',
#  'The',
#  'script',
#  'is',
#  'like',
#  'a',
#  'guide',
#  'for',
#  'the',
#  'movie',
#  ',',
#  'telling',
#  'what',
#  'happens',
#  'and',
#  'what',
#  'people',
#  'say',
#  '.',
#  'The',
#  'people',
#  'who',
#  'act',
#  'in',
#  'the',
#  'film',
#  'are',
#  'called',
#  'actors',
#  '.',
#  'They',
#  'play',
#  'various',
#  'roles',
#  ',',
#  'pretending',
#  'to',
#  'be',
#  'someone',
#  'else',
#  '.',
#  'Some',
#  'films',
#  'are',
#  'based',
#  'on',
#  'true',
#  'stories',
# ...

# %%
pos_tagged_words = nltk.pos_tag(tokens)

# %%
noun_list = []
non_noun = []
for i,j in pos_tagged_words:
    if j not in ['PRP','NN']:
        print(i)
        non_noun.append(i)
    else:
        print(i)
        noun_list.append(i)
# Out:
# Films
# ,
# often
# called
# movies
# ,
# are
# a
# major
# part
# of
# our
# lives
# and
# culture
# .
# These
# are
# stories
# brought
# to
# life
# on
# big
# screens
# with
# moving
# pictures
# and
# sound
# .
# Each
# film
# starts
# as
# an
# idea
# ,
# which
# then
# becomes
# a
# script
# .
# The
# script
# is
# like
# a
# guide
# for
# the
# movie
# ,
# telling
# what
# happens
# and
# what
# people
# say
# .
# The
# people
# who
# act
# in
# the
# film
# are
# called
# actors
# .
# They
# play
# various
# roles
# ,
# pretending
# to
# be
# someone
# else
# .
# Some
# films
# are
# based
# on
# true
# stories
# and
# some
# are
# imagined
# .
# Films
# are
# made
# in
# many
# genres
# ,
# like
# comedy
# ,
# action
# ,
# drama
# ,
# and
# horror
# ,
# each
# offering
# a
# different
# experience
# .
# Comedies
# make
# us
# laugh
# ,
# dramas
# make
# us
# think
# ,
# horrors
# may
# scare
# us
# ,
# and
# action
# films
# thrill
# us
# .
# Films
# can
# teach
# us
# ...

# %%
from nltk.util import ngrams

# %%
input_text = "Films, often called movies, are a major part of our lives and culture. These are stories brought to life on big screens with moving pictures and sound. Each film starts as an idea, which then becomes a script. The script is like a guide for the movie, telling what happens and what people say. The people who act in the film are called actors. They play various roles, pretending to be someone else. Some films are based on true stories and some are imagined. Films are made in many genres, like comedy, action, drama, and horror, each offering a different experience. Comedies make us laugh, dramas make us think, horrors may scare us, and action films thrill us. Films can teach us about different people, cultures, and ideas, and can even make us see the world in a new way. They can also be a fun way to escape from the real world for a little while. Making a film requires a big team. Along with actors, there are directors who guide the filming process, camera operators who film the scenes, and editors who put all the parts together. After the film is made, it is shown in cinemas where we can watch it, usually with popcorn! Films are special because they tell stories in a way that no other art form can, combining visuals, sound, and performance all at once."

# %%
input_text
tokens = word_tokenize(input_text)

# %%
len(tokens)
# Out:
# 270

# %%
ngrams(tokens,2)

# %%
gram_1 = list(ngrams(tokens,2))

# %%
gram_1
# Out:
# [('Films', ','),
#  (',', 'often'),
#  ('often', 'called'),
#  ('called', 'movies'),
#  ('movies', ','),
#  (',', 'are'),
#  ('are', 'a'),
#  ('a', 'major'),
#  ('major', 'part'),
#  ('part', 'of'),
#  ('of', 'our'),
#  ('our', 'lives'),
#  ('lives', 'and'),
#  ('and', 'culture'),
#  ('culture', '.'),
#  ('.', 'These'),
#  ('These', 'are'),
#  ('are', 'stories'),
#  ('stories', 'brought'),
#  ('brought', 'to'),
#  ('to', 'life'),
#  ('life', 'on'),
#  ('on', 'big'),
#  ('big', 'screens'),
#  ('screens', 'with'),
#  ('with', 'moving'),
#  ('moving', 'pictures'),
#  ('pictures', 'and'),
#  ('and', 'sound'),
#  ('sound', '.'),
#  ('.', 'Each'),
#  ('Each', 'film'),
#  ('film', 'starts'),
#  ('starts', 'as'),
#  ('as', 'an'),
#  ('an', 'idea'),
#  ('idea', ','),
#  (',', 'which'),
#  ('which', 'then'),
#  ('then', 'becomes'),
#  ('becomes', 'a'),
#  ('a', 'script'),
#  ('script', '.'),
#  ('.', 'The'),
#  ('The', 'script'),
#  ('script', 'is'),
#  ('is', 'like'),
#  ('like', 'a'),
# ...

# %%
gram_2 = list(ngrams(tokens,3))

# %%
gram_2
# Out:
# [('Films', ',', 'often'),
#  (',', 'often', 'called'),
#  ('often', 'called', 'movies'),
#  ('called', 'movies', ','),
#  ('movies', ',', 'are'),
#  (',', 'are', 'a'),
#  ('are', 'a', 'major'),
#  ('a', 'major', 'part'),
#  ('major', 'part', 'of'),
#  ('part', 'of', 'our'),
#  ('of', 'our', 'lives'),
#  ('our', 'lives', 'and'),
#  ('lives', 'and', 'culture'),
#  ('and', 'culture', '.'),
#  ('culture', '.', 'These'),
#  ('.', 'These', 'are'),
#  ('These', 'are', 'stories'),
#  ('are', 'stories', 'brought'),
#  ('stories', 'brought', 'to'),
#  ('brought', 'to', 'life'),
#  ('to', 'life', 'on'),
#  ('life', 'on', 'big'),
#  ('on', 'big', 'screens'),
#  ('big', 'screens', 'with'),
#  ('screens', 'with', 'moving'),
#  ('with', 'moving', 'pictures'),
#  ('moving', 'pictures', 'and'),
#  ('pictures', 'and', 'sound'),
#  ('and', 'sound', '.'),
#  ('sound', '.', 'Each'),
#  ('.', 'Each', 'film'),
#  ('Each', 'film', 'starts'),
#  ('film', 'starts', 'as'),
#  ('starts', 'as', 'an'),
# ...

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sample_text ="Films, often called movies, are a major part of our lives and culture. These are stories brought to life on big screens with moving pictures and sound. Each film starts as an idea, which then becomes a script. The script is like a guide for the movie, telling what happens and what people say. The people who act in the film are called actors. They play various roles, pretending to be someone else. Some films are based on true stories and some are imagined. Films are made in many genres, like comedy, action, drama, and horror, each offering a different experience. Comedies make us laugh, dramas make us think, horrors may scare us, and action films thrill us. Films can teach us about different people, cultures, and ideas, and can even make us see the world in a new way. They can also be a fun way to escape from the real world for a little while. Making a film requires a big team. Along with actors, there are directors who guide the filming process, camera operators who film the scenes, and editors who put all the parts together. After the film is made, it is shown in cinemas where we can watch it, usually with popcorn! Films are special because they tell stories in a way that no other art form can, combining visuals, sound, and performance all at once."

# %%
word_tokenize(sample_text)
# Out:
# ['Films',
#  ',',
#  'often',
#  'called',
#  'movies',
#  ',',
#  'are',
#  'a',
#  'major',
#  'part',
#  'of',
#  'our',
#  'lives',
#  'and',
#  'culture',
#  '.',
#  'These',
#  'are',
#  'stories',
#  'brought',
#  'to',
#  'life',
#  'on',
#  'big',
#  'screens',
#  'with',
#  'moving',
#  'pictures',
#  'and',
#  'sound',
#  '.',
#  'Each',
#  'film',
#  'starts',
#  'as',
#  'an',
#  'idea',
#  ',',
#  'which',
#  'then',
#  'becomes',
#  'a',
#  'script',
#  '.',
#  'The',
#  'script',
#  'is',
#  'like',
#  'a',
#  'guide',
#  'for',
#  'the',
#  'movie',
#  ',',
#  'telling',
#  'what',
#  'happens',
#  'and',
#  'what',
#  'people',
#  'say',
#  '.',
#  'The',
#  'people',
#  'who',
#  'act',
#  'in',
#  'the',
#  'film',
#  'are',
#  'called',
#  'actors',
#  '.',
#  'They',
#  'play',
#  'various',
#  'roles',
#  ',',
#  'pretending',
#  'to',
#  'be',
#  'someone',
#  'else',
#  '.',
#  'Some',
#  'films',
#  'are',
#  'based',
#  'on',
#  'true',
#  'stories',
# ...

# %%
tokens = word_tokenize(sample_text)

# %%
tokens
# Out:
# ['Films',
#  ',',
#  'often',
#  'called',
#  'movies',
#  ',',
#  'are',
#  'a',
#  'major',
#  'part',
#  'of',
#  'our',
#  'lives',
#  'and',
#  'culture',
#  '.',
#  'These',
#  'are',
#  'stories',
#  'brought',
#  'to',
#  'life',
#  'on',
#  'big',
#  'screens',
#  'with',
#  'moving',
#  'pictures',
#  'and',
#  'sound',
#  '.',
#  'Each',
#  'film',
#  'starts',
#  'as',
#  'an',
#  'idea',
#  ',',
#  'which',
#  'then',
#  'becomes',
#  'a',
#  'script',
#  '.',
#  'The',
#  'script',
#  'is',
#  'like',
#  'a',
#  'guide',
#  'for',
#  'the',
#  'movie',
#  ',',
#  'telling',
#  'what',
#  'happens',
#  'and',
#  'what',
#  'people',
#  'say',
#  '.',
#  'The',
#  'people',
#  'who',
#  'act',
#  'in',
#  'the',
#  'film',
#  'are',
#  'called',
#  'actors',
#  '.',
#  'They',
#  'play',
#  'various',
#  'roles',
#  ',',
#  'pretending',
#  'to',
#  'be',
#  'someone',
#  'else',
#  '.',
#  'Some',
#  'films',
#  'are',
#  'based',
#  'on',
#  'true',
#  'stories',
# ...

# %%
sent_tokenize(sample_text)
# Out:
# ['Films, often called movies, are a major part of our lives and culture.',
#  'These are stories brought to life on big screens with moving pictures and sound.',
#  'Each film starts as an idea, which then becomes a script.',
#  'The script is like a guide for the movie, telling what happens and what people say.',
#  'The people who act in the film are called actors.',
#  'They play various roles, pretending to be someone else.',
#  'Some films are based on true stories and some are imagined.',
#  'Films are made in many genres, like comedy, action, drama, and horror, each offering a different experience.',
#  'Comedies make us laugh, dramas make us think, horrors may scare us, and action films thrill us.',
#  'Films can teach us about different people, cultures, and ideas, and can even make us see the world in a new way.',
#  'They can also be a fun way to escape from the real world for a little while.',
#  'Making a film requires a big team.',
# ...

# %%
" ".join(tokens)

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sample_text ="Films, often called movies, are a major part of our lives and culture. These are stories brought to life on big screens with moving pictures and sound. Each film starts as an idea, which then becomes a script. The script is like a guide for the movie, telling what happens and what people say. The people who act in the film are called actors. They play various roles, pretending to be someone else. Some films are based on true stories and some are imagined. Films are made in many genres, like comedy, action, drama, and horror, each offering a different experience. Comedies make us laugh, dramas make us think, horrors may scare us, and action films thrill us. Films can teach us about different people, cultures, and ideas, and can even make us see the world in a new way. They can also be a fun way to escape from the real world for a little while. Making a film requires a big team. Along with actors, there are directors who guide the filming process, camera operators who film the scenes, and editors who put all the parts together. After the film is made, it is shown in cinemas where we can watch it, usually with popcorn! Films are special because they tell stories in a way that no other art form can, combining visuals, sound, and performance all at once."

# %%
sample_text
# Out:
# 'Films, often called movies, are a major part of our lives and culture. These are stories brought to life on big screens with moving pictures and sound. Each film starts as an idea, which then becomes a script. The script is like a guide for the movie, telling what happens and what people say. The people who act in the film are called actors. They play various roles, pretending to be someone else. Some films are based on true stories and some are imagined. Films are made in many genres, like comedy, action, drama, and horror, each offering a different experience. Comedies make us laugh, dramas make us think, horrors may scare us, and action films thrill us. Films can teach us about different people, cultures, and ideas, and can even make us see the world in a new way. They can also be a fun way to escape from the real world for a little while. Making a film requires a big team. Along with actors, there are directors who guide the filming process, camera operators who film the scenes,
# ...

# %%
sent_ment = SentimentIntensityAnalyzer()

# %%
sent_score = sent_ment.polarity_scores(sample_text)

# %%
sent_score
# Out:
# {'neg': 0.051, 'neu': 0.824, 'pos': 0.124, 'compound': 0.9336}

# %%
sent_score['compound']
# Out:
# 0.9336

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
input_text="Films, often called movies, are a major part of our lives and culture. These are stories brought to life on big screens with moving pictures and sound. Each film starts as an idea, which then becomes a script. The script is like a guide for the movie, telling what happens and what people say. The people who act in the film are called actors. They play various roles, pretending to be someone else. Some films are based on true stories and some are imagined. Films are made in many genres, like comedy, action, drama, and horror, each offering a different experience. Comedies make us laugh, dramas make us think, horrors may scare us, and action films thrill us. Films can teach us about different people, cultures, and ideas, and can even make us see the world in a new way. They can also be a fun way to escape from the real world for a little while. Making a film requires a big team. Along with actors, there are directors who guide the filming process, camera operators who film the scenes, and editors who put all the parts together. After the film is made, it is shown in cinemas where we can watch it, usually with popcorn! Films are special because they tell stories in a way that no other art form can, combining visuals, sound, and performance all at once."

# %%
vect = CountVectorizer(stop_words="english")

# %%
ext_val = vect.fit_transform([input_text])

# %%
vect.get_feature_names_out()
# Out:
# array(['act', 'action', 'actors', 'art', 'based', 'big', 'brought',
#        'called', 'camera', 'cinemas', 'combining', 'comedies', 'comedy',
#        'culture', 'cultures', 'different', 'directors', 'drama', 'dramas',
#        'editors', 'escape', 'experience', 'film', 'filming', 'films',
#        'form', 'fun', 'genres', 'guide', 'happens', 'horror', 'horrors',
#        'idea', 'ideas', 'imagined', 'laugh', 'life', 'like', 'little',
#        'lives', 'major', 'make', 'making', 'movie', 'movies', 'moving',
#        'new', 'offering', 'operators', 'parts', 'people', 'performance',
#        'pictures', 'play', 'popcorn', 'pretending', 'process', 'real',
#        'requires', 'roles', 'say', 'scare', 'scenes', 'screens', 'script',
#        'shown', 'sound', 'special', 'starts', 'stories', 'teach', 'team',
#        'tell', 'telling', 'think', 'thrill', 'true', 'usually', 'various',
#        'visuals', 'watch', 'way', 'world'], dtype=object)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
w_c = WordCloud(width=1000,height=500,background_color="green").generate(sample_text)

plt.figure(figsize=(14,6))
plt.imshow(w_c)
plt.axis('off')
plt.show()
